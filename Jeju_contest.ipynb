# %%
import pandas as pd
train=pd.read_csv('./201901-202003.csv')

# %%
train
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 0           201901           강원         강릉시  건강보조식품 소매업          강원
# 1           201901           강원         강릉시  건강보조식품 소매업          강원
# 2           201901           강원         강릉시  건강보조식품 소매업          강원
# 3           201901           강원         강릉시  건강보조식품 소매업          강원
# 4           201901           강원         강릉시  건강보조식품 소매업          강원
# ...            ...          ...         ...         ...         ...
# 24697787    202003           충북         충주시    휴양콘도 운영업          충북
# 24697788    202003           충북         충주시    휴양콘도 운영업          충북
# 24697789    202003           충북         충주시    휴양콘도 운영업          충북
# 24697790    202003           충북         충주시    휴양콘도 운영업          충북
# 24697791    202003           충북         충주시    휴양콘도 운영업          충북
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 0               강릉시  20s            1    1          4   311200    4
# ...

# %%
jeju=train[train['CARD_SIDO_NM'].isin(['제주'])]
jeju
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM STD_CLSS_NM HOM_SIDO_NM  \
# 1454855     201901           제주        서귀포시  건강보조식품 소매업          부산
# 1454856     201901           제주        서귀포시  건강보조식품 소매업          인천
# 1454857     201901           제주        서귀포시  건강보조식품 소매업          제주
# 1454858     201901           제주        서귀포시  건강보조식품 소매업          제주
# 1454859     201901           제주        서귀포시  건강보조식품 소매업          제주
# ...            ...          ...         ...         ...         ...
# 24597421    202003           제주         제주시    휴양콘도 운영업          서울
# 24597422    202003           제주         제주시    휴양콘도 운영업          제주
# 24597423    202003           제주         제주시    휴양콘도 운영업          제주
# 24597424    202003           제주         제주시    휴양콘도 운영업          제주
# 24597425    202003           제주         제주시    휴양콘도 운영업          제주
#
#          HOM_CCG_NM  AGE  SEX_CTGO_CD  FLC  CSTMR_CNT      AMT  CNT
# 1454855         사하구  50s            2    4          4  1900000    4
# ...

# %%
import sqlite3

# %%
conn=sqlite3.connect('jeju_con.db')

# %%
jeju.to_sql('jeju_table',conn,if_exists='replace')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-32481e69e353> in <module>
# ----> 1 commit()
#
# NameError: name 'commit' is not defined
